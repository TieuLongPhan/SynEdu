# %%
import pyfiglet

banner = pyfiglet.figlet_format("SynEdu", font="standard")
print(banner)
# Out:
#  ____              _____    _
# / ___| _   _ _ __ | ____|__| |_   _
# \___ \| | | | '_ \|  _| / _` | | | |
#  ___) | |_| | | | | |__| (_| | |_| |
# |____/ \__, |_| |_|_____\__,_|\__,_|
#        |___/

# %%
# !pip install art
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 610.4/610.4 kB 16.2 MB/s  0:00:00
# ...

# %%
from art import text2art

print(text2art("SynEdu"))
# Out:
#  ____                 _____      _
# / ___|  _   _  _ __  | ____|  __| | _   _
# \___ \ | | | || '_ \ |  _|   / _` || | | |
#  ___) || |_| || | | || |___ | (_| || |_| |
# |____/  \__, ||_| |_||_____| \__,_| \__,_|
#         |___/

# %%
 ____              _____    _       
/ ___| _   _ _ __ | ____|__| |_   _ 
\___ \| | | | '_ \|  _| / _` | | | |
 ___) | |_| | | | | |__| (_| | |_| |
|____/ \__, |_| |_|_____\__,_|\__,_|
       |___/
